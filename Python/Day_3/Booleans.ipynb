# %%
a = True #1
b = False #0

# %%
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
print(bool(False))
print(bool(None))
print(bool(0))
print(bool(""))
print(bool(()))
print(bool([]))
print(bool({}))
# Out:
# False
# False
# False
# False
# False
# False
# False

# %%
print(bool(6))
print(bool("h"))
print(bool((1,)))
print(bool([1,True]))
print(bool({1,2,3}))
# Out:
# True
# True
# True
# True
# True

# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %%
a = 200
b = 330

if b > a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# b is greater than a

# %%
print(b > a)
# Out:
# True
